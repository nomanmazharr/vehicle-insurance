# %%
import pandas as pd
import pymongo
from pymongo import MongoClient

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
df = df.to_dict(orient='records')

# %%
df
# Out:
# [{'id': 1,
#   'Gender': 'Male',
#   'Age': 44,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '> 2 Years',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 40454.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 217,
#   'Response': 1},
#  {'id': 2,
#   'Gender': 'Male',
#   'Age': 76,
#   'Driving_License': 1,
#   'Region_Code': 3.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 33536.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 183,
#   'Response': 0},
#  {'id': 3,
#   'Gender': 'Male',
#   'Age': 47,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '> 2 Years',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 38294.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 27,
#   'Response': 1},
#  {'id': 4,
#   'Gender': 'Male',
#   'Age': 21,
#   'Driving_License': 1,
#   'Region_Code': 11.0,
# ...

# %%
uri = "mongodb+srv://?retryWrites=true&w=majority&appName=VehicleCluster"

# %%
client = MongoClient(uri)

# %%
db = client['vehicleinsurace']
collection = db['vehicle']

# %%
records = collection.insert_many(df)

# %%
list(collection.find())
# Out:
# [{'_id': ObjectId('6861f2ff42860660eaa3d5ed'),
#   'id': 1,
#   'Gender': 'Male',
#   'Age': 44,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '> 2 Years',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 40454.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 217,
#   'Response': 1},
#  {'_id': ObjectId('6861f2ff42860660eaa3d5ee'),
#   'id': 2,
#   'Gender': 'Male',
#   'Age': 76,
#   'Driving_License': 1,
#   'Region_Code': 3.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '1-2 Year',
#   'Vehicle_Damage': 'No',
#   'Annual_Premium': 33536.0,
#   'Policy_Sales_Channel': 26.0,
#   'Vintage': 183,
#   'Response': 0},
#  {'_id': ObjectId('6861f2ff42860660eaa3d5ef'),
#   'id': 3,
#   'Gender': 'Male',
#   'Age': 47,
#   'Driving_License': 1,
#   'Region_Code': 28.0,
#   'Previously_Insured': 0,
#   'Vehicle_Age': '> 2 Years',
#   'Vehicle_Damage': 'Yes',
#   'Annual_Premium': 38294.0,
#   'Policy_Sales_Channel': 26.0,
# ...
